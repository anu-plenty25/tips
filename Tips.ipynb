# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tip = pd.read_csv("tips.csv")
tip
# Out:
#      total_bill     tip  gender smoker   day    time  size
# 0       2125.50  360.79    Male     No  Thur   Lunch     1
# 1       2727.18  259.42  Female     No   Sun  Dinner     5
# 2       1066.02  274.68  Female    Yes  Thur  Dinner     4
# 3       3493.45  337.90  Female     No   Sun  Dinner     1
# 4       3470.56  567.89    Male    Yes   Sun   Lunch     6
# ..          ...     ...     ...    ...   ...     ...   ...
# 739     3164.27  645.28    Male     No   Sat  Dinner     3
# 740     2962.62  218.00  Female    Yes   Sat  Dinner     2
# 741     2471.03  218.00    Male    Yes   Sat  Dinner     2
# 742     1942.38  190.75    Male     No   Sat  Dinner     2
# 743     2047.02  327.00  Female     No  Thur  Dinner     2
#
# [744 rows x 7 columns]

# %%
tip.head(10)
# Out:
#    total_bill     tip  gender smoker   day    time  size
# 0     2125.50  360.79    Male     No  Thur   Lunch     1
# 1     2727.18  259.42  Female     No   Sun  Dinner     5
# 2     1066.02  274.68  Female    Yes  Thur  Dinner     4
# 3     3493.45  337.90  Female     No   Sun  Dinner     1
# 4     3470.56  567.89    Male    Yes   Sun   Lunch     6
# 5     2411.08  296.48  Female    Yes  Thur   Lunch     2
# 6     4607.43  374.96  Female     No  Thur  Dinner     4
# 7     1165.21  700.87  Female     No   Mon  Dinner     2
# 8     2895.04  347.71    Male     No   Sat  Dinner     5
# 9     2622.54  253.97    Male    Yes  Thur   Lunch     6

# %%
tip.shape
# Out:
# (744, 7)

# %%
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  744 non-null    float64
#  1   tip         744 non-null    float64
#  2   gender      744 non-null    object
#  3   smoker      744 non-null    object
#  4   day         744 non-null    object
#  5   time        744 non-null    object
#  6   size        744 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 29.1+ KB

# %%
tip.sample(10)
# Out:
#      total_bill     tip  gender smoker   day    time  size
# 723     1741.82  327.00  Female     No   Fri   Lunch     3
# 197     1751.63  171.13    Male    Yes   Fri   Lunch     6
# 251     2636.71  342.26  Female    Yes   Mon   Lunch     1
# 252     2997.50  524.29  Female     No   Sat   Lunch     6
# 128     2394.73  208.19  Female    Yes   Wed   Lunch     6
# 549     1966.36  327.00    Male     No   Sun  Dinner     2
# 172     2963.71  456.71  Female    Yes  Thur  Dinner     5
# 571     1860.63  327.00  Female     No   Sat  Dinner     3
# 210     2375.11  464.34    Male    Yes   Wed   Lunch     2
# 381     1915.13  341.17  Female    Yes   Sat  Dinner     1

# %%
tip.tail(10)
# Out:
#      total_bill     tip  gender smoker   day    time  size
# 734     1692.77  327.00    Male    Yes   Sat  Dinner     2
# 735     1097.63  136.25    Male     No   Sat  Dinner     2
# 736     1373.40  109.00    Male    Yes   Sat  Dinner     2
# 737     3578.47  127.53    Male    Yes   Sat  Dinner     2
# 738     3905.47  509.03  Female     No   Sat  Dinner     3
# 739     3164.27  645.28    Male     No   Sat  Dinner     3
# 740     2962.62  218.00  Female    Yes   Sat  Dinner     2
# 741     2471.03  218.00    Male    Yes   Sat  Dinner     2
# 742     1942.38  190.75    Male     No   Sat  Dinner     2
# 743     2047.02  327.00  Female     No  Thur  Dinner     2

# %%
#sum() join the element in a column together

tip.isnull().sum()
# Out:
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tip.describe()
# Out:
#         total_bill          tip        size
# count   744.000000   744.000000  744.000000
# mean   2165.006640   325.948091    3.180108
# std     954.248806   148.778225    1.532890
# min      44.690000     0.000000    1.000000
# 25%    1499.022500   218.000000    2.000000
# 50%    2102.610000   320.460000    3.000000
# 75%    2743.802500   415.562500    4.000000
# max    5538.290000  1090.000000    6.000000

# %%
tip.count()
# Out:
# total_bill    744
# tip           744
# gender        744
# smoker        744
# day           744
# time          744
# size          744
# dtype: int64

# %%
tip.duplicated().sum()
# Out:
# 1

# %%
sns.boxplot(x = "gender", y = "tip", data = tip);

# %%
sns.boxplot(x = "time",y = "tip", data = tip)

plt.ylabel("Amount of tip");

# %%
sns.scatterplot(x = 'time',y= 'day',data = tip);

# %%
sns.jointplot(x = "time",y = "tip",data = tip);

# %%
sns.barplot(x = "total_bill",y = "day",data = tip);

# %%
sns.scatterplot(x = "size",y = "tip",data=tip);

# %%
cat_df = tip.select_dtypes
cat_df
# Out:
# <bound method DataFrame.select_dtypes of      total_bill     tip  gender smoker   day    time  size
# 0       2125.50  360.79    Male     No  Thur   Lunch     1
# 1       2727.18  259.42  Female     No   Sun  Dinner     5
# 2       1066.02  274.68  Female    Yes  Thur  Dinner     4
# 3       3493.45  337.90  Female     No   Sun  Dinner     1
# 4       3470.56  567.89    Male    Yes   Sun   Lunch     6
# ..          ...     ...     ...    ...   ...     ...   ...
# 739     3164.27  645.28    Male     No   Sat  Dinner     3
# 740     2962.62  218.00  Female    Yes   Sat  Dinner     2
# 741     2471.03  218.00    Male    Yes   Sat  Dinner     2
# 742     1942.38  190.75    Male     No   Sat  Dinner     2
# 743     2047.02  327.00  Female     No  Thur  Dinner     2
#
# [744 rows x 7 columns]>
